# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/raw/naukri_data_science_jobs_india.csv")

# %%
df.head()
# Out:
#              Company                                 Location      education  \
# 0                UPL  Bangalore/Bengaluru, Mumbai (All Areas)  Post-graduate
# 1            Walmart                      Bangalore/Bengaluru  Post-graduate
# 2  SAP India Pvt.Ltd                      Bangalore/Bengaluru             UG
# 3                UPL  Bangalore/Bengaluru, Mumbai (All Areas)  Post-graduate
# 4            Walmart                      Bangalore/Bengaluru             UG
#
#                                   Skills/Description   job_type     salary  \
# 0  python, MLT, statistical modeling, machine lea...   contract   939957.0
# 1  Data Science, Machine learning, Python, Azure,...   contract  2060767.0
# 2  Python, IT Skills, Testing, Cloud, Product Man...  full-time   698970.0
# 3  python, machine learning, Data Science, data a...  full-time   529674.0
# 4  IT Skills, Python, Data Science, Machine Learn...   contract  2163829.0
#
# ...

# %%
df.tail()
# Out:
#                                   Company  \
# 11995  Krazy Mantra HR Solutions Pvt. Ltd
# 11996                          cliqhr.com
# 11997                       Serving Skill
# 11998                          cliqhr.com
# 11999           Huquo Consulting Pvt. Ltd
#
#                                                 Location       education  \
# 11995              Kolkata, Chennai, Bangalore/Bengaluru   Post-graduate
# 11996  Hyderabad/Secunderabad, Pune, Bangalore/Bengaluru   Post-graduate
# 11997        Hyderabad/Secunderabad, Bangalore/Bengaluru   Post-graduate
# 11998  Kochi/Cochin, Mumbai, Hyderabad/Secunderabad, ...   Post-graduate
# 11999                                Bangalore/Bengaluru  Under-graduate
#
#                                       Skills/Description   job_type  \
# 11995  Spark, Python, S3, lambda, Athena, AWS, IT Ski...  full-time
# 11996  AirFlow, BigQuery, GCS, Kafka, Java, Shell scr...   contract
# ...

# %%
df.shape
# Out:
# (12000, 8)

# %%
df.columns
# Out:
# Index(['Company', 'Location', 'education', 'Skills/Description', 'job_type',
#        'salary', 'Job Experience', 'Job_Role'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Company             12000 non-null  str
#  1   Location            12000 non-null  str
#  2   education           10324 non-null  str
#  3   Skills/Description  12000 non-null  str
#  4   job_type            10720 non-null  str
#  5   salary              11024 non-null  float64
#  6   Job Experience      12000 non-null  str
#  7   Job_Role            12000 non-null  str
# dtypes: float64(1), str(7)
# memory usage: 750.1 KB

# %%
df.describe(include="all")
# Out:
#           Company             Location education Skills/Description  job_type  \
# count       12000                12000     10324              12000     10720
# unique       3507                  822         6              11356         2
# top     Accenture  Bangalore/Bengaluru        UG     Data Scientist  contract
# freq          490                 3383      1757                  8      5366
# mean          NaN                  NaN       NaN                NaN       NaN
# std           NaN                  NaN       NaN                NaN       NaN
# min           NaN                  NaN       NaN                NaN       NaN
# 25%           NaN                  NaN       NaN                NaN       NaN
# 50%           NaN                  NaN       NaN                NaN       NaN
# 75%           NaN                  NaN       NaN                NaN       NaN
# max           NaN                  NaN       NaN                NaN       NaN
#
# ...

# %%
df.sample(5)
# Out:
#                                 Company  \
# 11982                     Serving Skill
# 6782     NOTUS SERVICES PRIVATE LIMITED
# 5716   Innova Solutions Private Limited
# 11279                         STEELMINT
# 8678       Gruppent Solutions Pvt. Ltd.
#
#                                                 Location      education  \
# 11982                                Bangalore/Bengaluru            NaN
# 6782   Kolkata, Hyderabad/Secunderabad, Pune, Ahmedab...            NaN
# 5716                                             Chennai             PG
# 11279                                     Jaipur, Raipur            NaN
# 8678                                             Kolkata  Post-graduate
#
#                                       Skills/Description   job_type  \
# 11982  Java, Hibernate, Full Stack, MySQL, Javascript...  full-time
# 6782   BigQuery, Dataflow, SQL, Dataproc, Firebase, C...   contract
# 5716   docker, EMR, Airflow, Python, Pyspark, AWS, IT...  full-time
# ...

# %%
df.isnull().sum()
# Out:
# Company                  0
# Location                 0
# education             1676
# Skills/Description       0
# job_type              1280
# salary                 976
# Job Experience           0
# Job_Role                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# Company                3507
# Location                822
# education                 6
# Skills/Description    11356
# job_type                  2
# salary                10990
# Job Experience           30
# Job_Role               6563
# dtype: int64
